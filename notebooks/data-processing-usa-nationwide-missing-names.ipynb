# %%
import os
os.chdir("../PycharmProjects/names-demo")
os.getcwd()
# Out:
# ['.git',
#  '.idea',
#  '.venv',
#  'assets',
#  'clustering',
#  'data',
#  'elections1.csv',
#  'elections2022.csv',
#  'elections2023.csv',
#  'images',
#  'json_files',
#  'main.py',
#  'migration.csv',
#  'modules',
#  'notebooks',
#  'packages.txt',
#  'pyproject.toml',
#  'qodana.yaml',
#  'requirements.txt',
#  'results',
#  'runtime.txt',
#  'temp',
#  'utils',
#  'viz',
#  '__init__.py']

# %%
import pandas as pd

# Veri setini yükle
df = pd.read_csv('/temp/1880-2024-male-data.csv')

# Aranan isimler listesi
target_names = ['Aiden', 'Brandon', 'Brian', 'Ethan', 'Gary', 'Jayden', 'Jeffrey', 'Justin', 'Liam', 'Lucas', 'Mateo', 'Ronald', 'Tyler']

# Yıl aralığını belirle (1880-2024)
all_years = set(range(1880, 2025))

results = {}

for name in target_names:
    # İsmin bulunduğu yılları bul
    present_years = set(df[df['name'] == name]['year'].unique())
    # Eksik yılları bul
    missing_years = sorted(list(all_years - present_years))
    results[name] = missing_years

# Sonuçları yazdır
print("Eksik Yıllar Raporu:")
print("-" * 30)
for name, years in results.items():
    if not years:
        print(f"{name}: Hiçbir yıl eksik değil.")
    else:
        # Yılları gruplandırarak daha okunabilir hale getirebiliriz (isteğe bağlı)
        # Şimdilik direkt listeyi yazdıralım
        print(f"{name}: {years}")
# Out:
# shape: (6_600_640, 7)
# ┌──────────┬────────┬──────┬────────┬───────┬─────────────┬──────┐
# │ state    ┆ gender ┆ year ┆ name   ┆ count ┆ total_count ┆ rank │
# │ ---      ┆ ---    ┆ ---  ┆ ---    ┆ ---   ┆ ---         ┆ ---  │
# │ str      ┆ str    ┆ i64  ┆ str    ┆ i64   ┆ i64         ┆ i32  │
# ╞══════════╪════════╪══════╪════════╪═══════╪═════════════╪══════╡
# │ Alaska   ┆ female ┆ 1910 ┆ Mary   ┆ 14    ┆ 68          ┆ 1    │
# │ Alabama  ┆ female ┆ 1910 ┆ Mary   ┆ 875   ┆ 13102       ┆ 1    │
# │ Arkansas ┆ female ┆ 1910 ┆ Mary   ┆ 408   ┆ 7539        ┆ 1    │
# │ Arizona  ┆ female ┆ 1910 ┆ Mary   ┆ 74    ┆ 586         ┆ 1    │
# │ …        ┆ …      ┆ …    ┆ …      ┆ …     ┆ …           ┆ …    │
# │ Texas    ┆ male   ┆ 2024 ┆ Zubair ┆ 5     ┆ 178308      ┆ 2605 │
# │ Texas    ┆ male   ┆ 2024 ┆ Zyion  ┆ 5     ┆ 178308      ┆ 2605 │
# │ Texas    ┆ male   ┆ 2024 ┆ Zylan  ┆ 5     ┆ 178308      ┆ 2605 │
# │ Texas    ┆ male   ┆ 2024 ┆ Zymere ┆ 5     ┆ 178308      ┆ 2605 │
# └──────────┴────────┴──────┴────────┴───────┴─────────────┴──────┘

# %%
import pandas as pd

# Veri setini yükle
df = pd.read_csv('temp/1880-2024-female-data.csv')


# Aranan isimler listesi
target_names = [
    'Alexis', 'Ashley', 'Brittany', 'Carol', 'Crystal', 'Debra', 'Harper', 'Heather', 'Jennifer', 'Karen', 'Kelly', 'Kimberly', 'Lauren',"Lisa","Lori", "Luna","Madison","Megan","Mia","Michelle","Nicole",
    "Pamela","Patricia","Sandra","Sharon","Shirley","Sofia","Stephanie","Tammy","Taylor","Tracy"]

# Yıl aralığını belirle (1880-2024)
all_years = set(range(1880, 2025))

results = {}

for name in target_names:
    # İsmin bulunduğu yılları bul
    present_years = set(df[df['name'] == name]['year'].unique())
    # Eksik yılları bul
    missing_years = sorted(list(all_years - present_years))
    results[name] = missing_years

# Sonuçları yazdır
print("Eksik Yıllar Raporu:")
print("-" * 30)
for name, years in results.items():
    if not years:
        print(f"{name}: Hiçbir yıl eksik değil.")
    else:
        # Yılları gruplandırarak daha okunabilir hale getirebiliriz (isteğe bağlı)
        # Şimdilik direkt listeyi yazdıralım
        print(f"{name}: {years}")
# Out:
# Eksik Yıllar Raporu:
# ------------------------------
# Alexis: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940]
# Ashley: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1939, 1940]
# Brittany: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962]
# Carol: [1883]
# Crystal: [1880, 1881, 1882, 1883, 1887]
# Debra: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1921]
# Harper: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1972, 1973, 1979]
# Heather: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1915, 1916, 1918, 1919, 1921, 1924, 1925, 1926, 1927, 1928]
# Jennifer: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918]
# Karen: [1880, 1882, 1883, 1884, 1895, 1902]
# Kelly: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1913]
# Kimberly: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932]
# Lauren: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1934, 1936, 1937, 1938]
# Lisa: [1880, 1881, 1882, 1883, 1884, 1885, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1897, 1898, 1900, 1901, 1902, 1903, 1906, 1908, 1909]
# Lori: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1928]
# Luna: [1882, 1947, 1953, 1955, 1959, 1961, 1963, 1965, 1966, 1967, 1968, 1971, 1973]
# Madison: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1972, 1973, 1974, 1976, 1977, 1978, 1979, 1980, 1982, 1983]
# Megan: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1925, 1928, 1929, 1932, 1937, 1938, 1941]
# Mia: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1934, 1935, 1936, 1937, 1938, 1939, 1941]
# Michelle: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1916, 1917, 1921]
# Nicole: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936]
# Pamela: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1896, 1897, 1899, 1900, 1901, 1902, 1903, 1905, 1907, 1908, 1909]
# Patricia: [1880, 1881, 1882, 1883]
# Sandra: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903]
# Sharon: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1901, 1902, 1903, 1904, 1905, 1906, 1908, 1910]
# Shirley: [1881]
# Sofia: [1880, 1882, 1883, 1884, 1885]
# Stephanie: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890]
# Tammy: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1936]
# Taylor: [1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1952, 1953, 1955, 1959, 1965]
# Tracy: [1880, 1881, 1882, 1883, 1904]
